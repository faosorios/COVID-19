# %% [markdown]
# # Segmented regression for assessing lockdown strategies for Chilean data

# %% [markdown]
# Segmented regression for assessing lockdown strategies for Chilean data using function 'segmented19' by Vito Muggeo (vito.muggeo@unipa.it)
#
# Reference: Muggeo VMR, Sottile G, Porcu M. (2020) Modelling COVID-19 outbreak:
# segmented regression to assess lockdown effectiveness (on ResearchGate)
#
# doi: 10.13140/RG.2.2.32798.28485

# %% [markdown]
# ## Load data

# %%
## downloaded from https://github.com/MinCiencia/Datos-COVID19/tree/master/output/producto3
chile <- read.csv(url("https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/output/producto3/CasosTotalesCumulativo_T.csv"))

# %%
dbnames <- c("Fecha", "Arica.y.Parinacota", "Tarapaca", "Antofagasta", "Atacama", "Coquimbo", "Valparaiso", "Metropolitana",
  "O.Higgins", "Maule", "Nuble", "Biobio", "Araucania", "Los.Rios", "Los.Lagos", "Aysen", "Magallanes", "Total")
names(chile) <- dbnames
npsi <- 1:15 # number of 'periods'
hundred <- ">=100" # more than 100 cases
zero <- ">=0" # more than 0 cases

# %% [markdown]
# ## Load libraries and sources

# %%
## loading required package
library(segmented)

## reading sources
source("segmented19.R")

# %%
now <- proc.time()  # for speed test

# %% [markdown]
# ## Fitting model using all data

# %%
## fitting models for each 'region'
y <- chile$Total
attr(y, "first.date") <- as.character(chile$Fecha[1])
oChile <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... 11 breakpoints selected by BIC

# %% [markdown]
# ## Fitting model for each country region

# %%
y <- chile$Arica.y.Parinacota
attr(y, "first.date") <- as.character(chile$Fecha[1])
oArica <- segmented19(y, npsi = npsi, rule = zero) # >= 0
# Out:
# Running  ... 3 breakpoints selected by BIC

# %%
y <- chile$Tarapaca
attr(y, "first.date") <- as.character(chile$Fecha[1])
oTarapaca <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... 5 breakpoints selected by BIC

# %%
y <- chile$Antofagasta
attr(y, "first.date") <- as.character(chile$Fecha[1])
oAntofagasta <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... breakpoint estimate(s): 13.6865 22.00989 23.28846 27.96325 30.9311 35.97358 40.33014
# breakpoint estimate(s): 7.769612 9.252797 24.77934 28.17013 30.92033 34.88726 37.65436 42.51388 47.76868 48.3964 50.35107
# breakpoint estimate(s): 10.39182 14.41723 15.16931 16.84804 19.80413 25.18464 31.20272 39.80027 47.24957 49.64878 51.19388 55.30957
# 2 breakpoints selected by BIC

# %%
y <- chile$Atacama
attr(y, "first.date") <- as.character(chile$Fecha[1])
oAtacama <- segmented19(y, npsi = npsi, rule = zero) # >= 0
# Out:
# Running  ... breakpoint estimate(s): 3.590097 12.1689 12.35015 26 26.67246 39.66608 46.30383 49.40582 57.33899 69.68825 76.75127 76.83538 86.8112 91.3175
# 3 breakpoints selected by BIC

# %%
y <- chile$Coquimbo
attr(y, "first.date") <- as.character(chile$Fecha[1])
oCoquimbo <- segmented19(y, npsi = npsi, rule = zero) # >= 0
# Out:
# Running  ... breakpoint estimate(s): 6.082084 17.0765 20.97038 32.2821 38.43914 47.24908 47.89885 53.22208 60.26248 64.69784 67.98924 83.37194 84.61838 86.67245
# 6 breakpoints selected by BIC

# %%
y <- chile$Valparaiso
attr(y, "first.date") <- as.character(chile$Fecha[1])
oValpo <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... 3 breakpoints selected by BIC

# %%
y <- chile$Metropolitana
attr(y, "first.date") <- as.character(chile$Fecha[1])
oStgo <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... breakpoint estimate(s): 11.97343 29.44545 44.98294 48.2768 49.08326 65.08738 67.97948 73.16016
# breakpoint estimate(s): 3.74041 4.72574 13.62227 28.40639 43.69245 49.99026 65.18618 68.87561 78.45242
# 7 breakpoints selected by BIC

# %%
y <- chile$O.Higgins
attr(y, "first.date") <- as.character(chile$Fecha[1])
oOHiggins <- segmented19(y, npsi = npsi, rule = zero) # >= 0
# Out:
# Running  ... breakpoint estimate(s): 17.07231 26.30893 28.65393 33.56428 51.08407 52.09863 65.55651 74.23163 81.60812
# 5 breakpoints selected by BIC

# %%
y <- chile$Maule
attr(y, "first.date") <- as.character(chile$Fecha[1])
oMaule <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... breakpoint estimate(s): 5.53873 10.44015 11.28988 14.58508 19.02721 24.85378 28.03761 30.93001 38.88554 56.31123 58.20453
# 4 breakpoints selected by BIC

# %%
y <- chile$Nuble
attr(y, "first.date") <- as.character(chile$Fecha[1])
oNuble <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... 3 breakpoints selected by BIC

# %%
y <- chile$Biobio
attr(y, "first.date") <- as.character(chile$Fecha[1])
oBiobio <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... breakpoint estimate(s): 9.647196 14.55696 21.04644 25.49304 29.15609 41.80984 42.42158 56.46213 62.77259 66.30687
# 4 breakpoints selected by BIC

# %%
y <- chile$Araucania
attr(y, "first.date") <- as.character(chile$Fecha[1])
oAraucania <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... breakpoint estimate(s): 6.002987 8.666049 13.54107 15.72622 30.32225 31.05445 36.08543 44.85151 56.73783 58.40448 64.07265
# 4 breakpoints selected by BIC

# %%
y <- chile$Los.Rios
attr(y, "first.date") <- as.character(chile$Fecha[1])
oLosRios <- segmented19(y, npsi = npsi, rule = zero) # >= 0
# Out:
# Running  ... 3 breakpoints selected by BIC

# %%
y <- chile$Los.Lagos
attr(y, "first.date") <- as.character(chile$Fecha[1])
oLosLagos <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... 3 breakpoints selected by BIC

# %%
y <- chile$Aysen
attr(y, "first.date") <- as.character(chile$Fecha[1])
oAysen <- segmented19(y, npsi = npsi, rule = zero) # >= 0
# Out:
# Running  ... breakpoint estimate(s): 12 20.08196 29.23177 33.05954 34.11594 49.11247 54.25148 74.44414 81.02469 90.73659
# breakpoint estimate(s): 9.503861 12 14.82078 21.96959 33.9913 41.54891 44.00146 49.31246 50.2467 59.27688 59.68378 79.01059
# 2 breakpoints selected by BIC

# %%
y <- chile$Magallanes
attr(y, "first.date") <- as.character(chile$Fecha[1])
oMagallanes <- segmented19(y, npsi = npsi, rule = hundred)
# Out:
# Running  ... breakpoint estimate(s): 1.946449 10.19688 19.50653 33.76432 40.02635 56.5056
# breakpoint estimate(s): 1.946449 10.19688 19.56977 38.17636 45.23548 58.51023 63.03998
# breakpoint estimate(s): 3.897129 10.81345 17.83436 24.14777 25.48094 33.00392 38.39953 45.42412 56.05802
# breakpoint estimate(s): 1.991168 10.44512 17.3049 18.23526 20.16096 20.61547 38.2655 42.52392 43.69425 58.02966 62.79317
# 3 breakpoints selected by BIC

# %%
# Profile speed
speed <- proc.time() - now
rm(now, y) # cleaning

# %% [markdown]
# ## Visualizations

# %%
plot(oChile, main = "Chile", col = c(2,4))
# Out:
# Plot with title “Chile”

# %%
plot(oArica, main = "Arica y Parinacota", col = c(2,4))
# Out:
# Plot with title “Arica y Parinacota”

# %%
plot(oTarapaca, main = "Tarapacá", col = c(2,4))
# Out:
# Plot with title “Tarapacá”

# %%
plot(oAntofagasta, main = "Antofagasta", col = c(2,4))
# Out:
# Plot with title “Antofagasta”

# %%
plot(oAtacama, main = "Atacama", col = c(2,4))
# Out:
# Plot with title “Atacama”

# %%
plot(oCoquimbo, main = "Coquimbo", col = c(2,4))
# Out:
# Plot with title “Coquimbo”

# %%
plot(oStgo, main = "Santiago", col = c(2,4))
# Out:
# Plot with title “Santiago”

# %%
plot(oOHiggins, main = "O'Higgins", col = c(2,4))
# Out:
# Plot with title “O'Higgins”

# %%
plot(oMaule, main = "Maule", col = c(2,4))
# Out:
# Plot with title “Maule”

# %%
plot(oNuble, main = "Ñuble", col = c(2,4))
# Out:
# Plot with title “Ñuble”

# %%
plot(oBiobio, main = "Biobío", col = c(2,4))
# Out:
# Plot with title “Biobío”

# %%
plot(oAraucania, main = "Araucanía", col = c(2,4))
# Out:
# Plot with title “Araucanía”

# %%
plot(oLosRios, main = "Los Ríos", col = c(2,4))
# Out:
# Plot with title “Los Ríos”

# %%
plot(oLosLagos, main = "Los Lagos", col = c(2,4))
# Out:
# Plot with title “Los Lagos”

# %%
plot(oAysen, main = "Aysén", col = c(2,4))
# Out:
# Plot with title “Aysén”

# %%
plot(oMagallanes, main = "Magallanes", col = c(2,4))
# Out:
# Plot with title “Magallanes”
